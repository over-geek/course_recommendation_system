# %%
import numpy as np
import pandas as pd
import json
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

df = pd.read_csv("dataset/edx_courses.csv")
df.head()
df.info()
df.drop_duplicates()
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               975 non-null    object
#  1   summary             922 non-null    object
#  2   n_enrolled          855 non-null    object
#  3   course_type         975 non-null    object
#  4   institution         975 non-null    object
#  5   instructors         972 non-null    object
#  6   Level               975 non-null    object
#  7   subject             975 non-null    object
#  8   language            975 non-null    object
#  9   subtitles           972 non-null    object
#  10  course_effort       975 non-null    object
#  11  course_length       975 non-null    object
#  12  price               975 non-null    object
#  13  course_description  935 non-null    object
#  14  course_syllabus     414 non-null    object
#  15  course_url          975 non-null    object
# dtypes: object(16)
# memory usage: 122.0+ KB
# title                   0
# summary                53
# n_enrolled            120
# course_type             0
# institution             0
# instructors             3
# Level                   0
# subject                 0
# language                0
# subtitles               3
# course_effort           0
# course_length           0
# price                   0
# course_description     40
# course_syllabus       561
# course_url              0
# dtype: int64

# %%
text_columns = ['summary', 'instructors', 'subtitles', 'course_description', 'course_syllabus']
df[text_columns] = df[text_columns].fillna('not available')

df.isnull().sum()
df.head()
df.isnull().sum()
# Out:
# title                   0
# summary                 0
# n_enrolled            120
# course_type             0
# institution             0
# instructors             0
# Level                   0
# subject                 0
# language                0
# subtitles               0
# course_effort           0
# course_length           0
# price                   0
# course_description      0
# course_syllabus         0
# course_url              0
# dtype: int64

# %%
df['text'] = df['title'] + ' ' + df['summary'] + ' ' + df['course_description'] + ' ' + df['course_url']
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['text'])

## compute cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

cosine_sim_list = cosine_sim.tolist()
with open('cosine_sim.json', 'w') as f:
  json.dump(cosine_sim_list, f)

df.to_json('course.json', orient='records')

# save cosine similarity matrix
np.save('cosine_sim.npy', cosine_sim)

# save dataframe as csv
df.to_csv('edx_courses_processed.csv', index=False)

# %%
def get_recommendations_by_title(title, cosine_sim=cosine_sim):
  if title not in df['title'].values:
    return f"Course titled '{title}' not found"
  idx = df[df['title'] == title].index[0]
  sim_scores = list(enumerate(cosine_sim[idx]))
  sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
  sim_scores = sim_scores[1:4]
  course_indices = [i[0] for i in sim_scores]
  return df[['title', 'summary', 'course_description', 'course_url']].iloc[course_indices]

# %%
recommended_courses = get_recommendations_by_title('Network and Security Foundations')
print(recommended_courses)
# Out:
#                                                  title  \
# 728                         IoT Networks and Protocols
# 721  Introduction to Open Source Networking Technol...
# 295                    Preparing to Network in English
#
#                                                summary  \
# 728  Learn about IoT networks and the protocols and...
# 721  Learn technical fundamentals needed to adopt S...
# 295  Learn the basics of networking while you grow ...
#
#                                     course_description  \
# 728  The Internet of Things (IoT) is expanding at a...
# 721  Explore open source networking projects, from ...
# 295  Networking in the business world is key to car...
#
#                                             course_url
# 728  https://www.edx.org/course/iot-networks-and-pr...
# 721  https://www.edx.org/course/introduction-to-ope...
# 295  https://www.edx.org/course/preparing-to-networ...

# %%
unique_values = df['subject'].unique()
print(unique_values)
# Out:
# ['Education & Teacher Training' 'Computer Science'
#  'Data Analysis & Statistics' 'Business & Management' 'Communication'
#  'Health & Safety' 'Math' 'Humanities' 'Ethics' 'Economics & Finance'
#  'Food & Nutrition' 'Biology & Life Sciences' 'Social Sciences'
#  'Architecture' 'Medicine' 'Environmental Studies' 'Chemistry'
#  'Art & Culture' 'Language' 'Engineering' 'Philosophy & Ethics'
#  'Electronics' 'History' 'Literature' 'Physics' 'Law' 'Design' 'Science'
#  'Music' 'Energy & Earth Sciences' 'Philanthropy']

# %%
def get_recommenations_by_subject(subject, cosine_sim=cosine_sim):
  subject_df = df[df['subject'].str.contains(subject, case=False, na=False)]

  if subject_df.empty:
    return f"No courses found for the subject '{subject}'"
  subject_df = subject_df.reset_index(drop=True)
  tfidf = TfidfVectorizer(stop_words='english')
  tfidf_matrix = tfidf.fit_transform(subject_df['text'])
  cosine_sim_subject = linear_kernel(tfidf_matrix, tfidf_matrix)

  recommendations = {}
  for idx, row in subject_df.iterrows():
      # Get the pairwise similarity scores of all courses with that course
      sim_scores = list(enumerate(cosine_sim_subject[idx]))

      # Sort the courses based on the similarity scores
      sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

      # Get the scores of the 3 most similar courses
      sim_scores = sim_scores[1:4]

      # Get the course indices
      course_indices = [i[0] for i in sim_scores]

      # Store the recommendations
      recommendations[row['title']] = subject_df[['title', 'summary', 'course_description']].iloc[course_indices]

  return recommendations

# %%
subject_recommendations = get_recommenations_by_subject('Math')
for title, recs in subject_recommendations.items():
  print(f"Recommendations for course '{title}' ")
  print(recs)
  print()
# Out:
# Recommendations for course 'Fat Chance: Probability from the Ground Up'
#                                                 title  \
# 26                            MathTrackX: Probability
# 23                             MathTrackX: Statistics
# 25  A-level Mathematics for Year 13 - Course 2: Ge...
#
#                                               summary  \
# 26  Understand probability and how it manifests in...
# 23  Understand fundamental concepts relating to st...
# 25  Develop your thinking skills, fluency and conf...
#
#                                    course_description
# 26  This course is part five of the MathTrackX XSe...
# 23  This course is part six of the MathTrackX XSer...
# 25  This course by Imperial College London is desi...
#
# Recommendations for course 'Introduction to Linear Models and Matrix Algebra'
#                                        title  \
# 11  The Math of Data Science: Linear Algebra
# 22          Data for Effective Policy Making
# 28        Linear Algebra I: Linear Equations
#
#                                               summary  \
# 11  This course is an introduction to linear algeb...
# 22  Take control of data and gain a better underst...
# 28  This course takes you through the first three ...
#
#                                    course_description
# 11  Linear algebra is at the core of all of modern...
# 22  In this age of information, data is available ...
# 28  Systems of equations live at the heart of line...
#
# Recommendations for course 'Introduction to Algebra'
#                                        title  \
# 12                  Introduction to Geometry
# 8        College Algebra and Problem Solving
# 11  The Math of Data Science: Linear Algebra
#
#                                               summary  \
# 12                                      not available
# 8   Learn the basics of Algebra while preparing fo...
# 11  This course is an introduction to linear algeb...
#
#                                    course_description
# 12  More than 2000 years ago, long before rockets ...
# 8   This course is part of Global Freshman Academy...
# 11  Linear algebra is at the core of all of modern...
#
# Recommendations for course 'Engineering Calculus and Differential Equations'
#                                 title  \
# 4                   Calculus Applied!
# 7             Pre-University Calculus
# 29  MathTrackX: Differential Calculus
#
#                                               summary  \
# 4   Apply tools of single-variable calculus to cre...
# 7          Prepare for Introductory Calculus courses.
# 29  Discover concepts and techniques relating to d...
#
#                                    course_description
# 4   In this course, we go beyond the calculus text...
# 7   Mathematics is the language of Science, Engine...
# 29  This course is part three of the MathTrackX XS...
#
# Recommendations for course 'Calculus Applied!'
#                                               title  \
# 3   Engineering Calculus and Differential Equations
# 27                                  AP® Calculus BC
# 7                           Pre-University Calculus
#
#                                               summary  \
# 3   Learn fundamental concepts of single-variable ...
# 27  Learn AP® Calculus BC topics from highly respe...
# 7          Prepare for Introductory Calculus courses.
#
#                                    course_description
# 3   How do electrical engineers find out all the c...
# 27  In this calculus course, you will learn all th...
# 7   Mathematics is the language of Science, Engine...
#
# Recommendations for course 'Precalculus'
#                                   title  \
# 8   College Algebra and Problem Solving
# 30        MathTrackX: Special Functions
# 4                     Calculus Applied!
#
#                                               summary  \
# 8   Learn the basics of Algebra while preparing fo...
# 30  Understand trigonometric, exponential and loga...
# 4   Apply tools of single-variable calculus to cre...
#
#                                    course_description
# 8   This course is part of Global Freshman Academy...
# 30  This course is part two of the MathTrackX XSer...
# 4   In this course, we go beyond the calculus text...
#
# Recommendations for course 'A-level Mathematics for Year 12 - Course 1: Algebraic Methods, Graphs and Applied Mathematics Methods'
#                                                 title  \
# 24  A-level Mathematics for Year 12 - Course 2: Ca...
# 16  A-level Mathematics for Year 13 - Course 1: Fu...
# 25  A-level Mathematics for Year 13 - Course 2: Ge...
#
#                                               summary  \
# 24                                      not available
# 16                                      not available
# 25  Develop your thinking skills, fluency and conf...
#
#                                    course_description
# 24                                      not available
# 16                                      not available
# 25  This course by Imperial College London is desi...
#
# Recommendations for course 'Pre-University Calculus'
#                        title  \
# 27           AP® Calculus BC
# 4          Calculus Applied!
# 13  Calculus 1B: Integration
#
#                                               summary  \
# 27  Learn AP® Calculus BC topics from highly respe...
# 4   Apply tools of single-variable calculus to cre...
# 13  Discover the integral—what it is and how to co...
#
#                                    course_description
# 27  In this calculus course, you will learn all th...
# 4   In this course, we go beyond the calculus text...
# 13  How long should the handle of your spoon be so...
#
# Recommendations for course 'College Algebra and Problem Solving'
#                                  title  \
# 5                          Precalculus
# 28  Linear Algebra I: Linear Equations
# 30       MathTrackX: Special Functions
#
#                                               summary  \
# 5   This college-level, credit-eligible Precalculu...
# 28  This course takes you through the first three ...
# 30  Understand trigonometric, exponential and loga...
#
#                                    course_description
# 5   This course is part of Global Freshman Academy...
# 28  Systems of equations live at the heart of line...
# 30  This course is part two of the MathTrackX XSer...
#
# Recommendations for course 'Bases Matemáticas: Álgebra'
#                                         title  \
# 18               Bases Matemáticas: Derivadas
# 15              Bases Matemáticas: Integrales
# 14  Bases Matemáticas: Números y terminología
#
#                                               summary  \
# 18  Curso básico sobre funciones y sus derivadas, ...
# 15  Se repasan el concepto de primitiva, las primi...
# 14  Se repasan los conceptos básicos de conjuntos,...
#
#                                    course_description
# 18  Este curso se concibe como una revisión de los...
# 15  Este curso se concibe como una revisión de los...
# 14  Este curso está concebido como una preparación...
#
# Recommendations for course 'MathTrackX: Polynomials, Functions and Graphs'
#                                 title  \
# 30      MathTrackX: Special Functions
# 29  MathTrackX: Differential Calculus
# 19      MathTrackX: Integral Calculus
#
#                                               summary  \
# 30  Understand trigonometric, exponential and loga...
# 29  Discover concepts and techniques relating to d...
# 19  Discover concepts and techniques relating to i...
#
#                                    course_description
# 30  This course is part two of the MathTrackX XSer...
# 29  This course is part three of the MathTrackX XS...
# 19  This course is part four of the MathTrackX XSe...
#
# Recommendations for course 'The Math of Data Science: Linear Algebra'
#                                                title  \
# 28                Linear Algebra I: Linear Equations
# 1   Introduction to Linear Models and Matrix Algebra
# 8                College Algebra and Problem Solving
#
#                                               summary  \
# 28  This course takes you through the first three ...
# 1   Learn to use R programming to apply linear mod...
# 8   Learn the basics of Algebra while preparing fo...
#
#                                    course_description
# 28  Systems of equations live at the heart of line...
# 1   Matrix Algebra underlies many of the current t...
# 8   This course is part of Global Freshman Academy...
#
# Recommendations for course 'Introduction to Geometry'
#                        title  \
# 2    Introduction to Algebra
# 13  Calculus 1B: Integration
# 7    Pre-University Calculus
#
#                                               summary  \
# 2   Solve equations, draw graphs, and play with qu...
# 13  Discover the integral—what it is and how to co...
# 7          Prepare for Introductory Calculus courses.
#
#                                    course_description
# 2   We live in a world of numbers. You see them ev...
# 13  How long should the handle of your spoon be so...
# 7   Mathematics is the language of Science, Engine...
#
# Recommendations for course 'Calculus 1B: Integration'
#                       title  \
# 27          AP® Calculus BC
# 7   Pre-University Calculus
# 4         Calculus Applied!
#
#                                               summary  \
# 27  Learn AP® Calculus BC topics from highly respe...
# 7          Prepare for Introductory Calculus courses.
# 4   Apply tools of single-variable calculus to cre...
#
#                                    course_description
# 27  In this calculus course, you will learn all th...
# 7   Mathematics is the language of Science, Engine...
# 4   In this course, we go beyond the calculus text...
#
# Recommendations for course 'Bases Matemáticas: Números y terminología'
#                             title  \
# 15  Bases Matemáticas: Integrales
# 18   Bases Matemáticas: Derivadas
# 9      Bases Matemáticas: Álgebra
#
#                                               summary  \
# 15  Se repasan el concepto de primitiva, las primi...
# 18  Curso básico sobre funciones y sus derivadas, ...
# 9   En este curso se tratan los sistemas de ecuaci...
#
#                                    course_description
# 15  Este curso se concibe como una revisión de los...
# 18  Este curso se concibe como una revisión de los...
# 9   En este curso se recordará lo que es una ecuac...
#
# Recommendations for course 'Bases Matemáticas: Integrales'
#                                         title  \
# 18               Bases Matemáticas: Derivadas
# 14  Bases Matemáticas: Números y terminología
# 9                  Bases Matemáticas: Álgebra
#
#                                               summary  \
# 18  Curso básico sobre funciones y sus derivadas, ...
# 14  Se repasan los conceptos básicos de conjuntos,...
# 9   En este curso se tratan los sistemas de ecuaci...
#
#                                    course_description
# 18  Este curso se concibe como una revisión de los...
# 14  Este curso está concebido como una preparación...
# 9   En este curso se recordará lo que es una ecuac...
#
# Recommendations for course 'A-level Mathematics for Year 13 - Course 1: Functions, Sequences and Series, and Numerical Methods'
#                                                 title  \
# 6   A-level Mathematics for Year 12 - Course 1: Al...
# 24  A-level Mathematics for Year 12 - Course 2: Ca...
# 25  A-level Mathematics for Year 13 - Course 2: Ge...
#
#                                               summary  \
# 6                                       not available
# 24                                      not available
# 25  Develop your thinking skills, fluency and conf...
#
#                                    course_description
# 6                                       not available
# 24                                      not available
# 25  This course by Imperial College London is desi...
#
# Recommendations for course 'More Fun with Prime Numbers'
#                                                 title  \
# 2                             Introduction to Algebra
# 10      MathTrackX: Polynomials, Functions and Graphs
# 24  A-level Mathematics for Year 12 - Course 2: Ca...
#
#                                               summary  \
# 2   Solve equations, draw graphs, and play with qu...
# 10  Develop an understanding of polynomials, funct...
# 24                                      not available
#
#                                    course_description
# 2   We live in a world of numbers. You see them ev...
# 10  This course is part one of the MathTrackX XSer...
# 24                                      not available
#
# Recommendations for course 'Bases Matemáticas: Derivadas'
#                                         title  \
# 15              Bases Matemáticas: Integrales
# 14  Bases Matemáticas: Números y terminología
# 9                  Bases Matemáticas: Álgebra
#
#                                               summary  \
# 15  Se repasan el concepto de primitiva, las primi...
# 14  Se repasan los conceptos básicos de conjuntos,...
# 9   En este curso se tratan los sistemas de ecuaci...
#
#                                    course_description
# 15  Este curso se concibe como una revisión de los...
# 14  Este curso está concebido como una preparación...
# 9   En este curso se recordará lo que es una ecuac...
#
# Recommendations for course 'MathTrackX: Integral Calculus'
#                                 title  \
# 29  MathTrackX: Differential Calculus
# 23             MathTrackX: Statistics
# 26            MathTrackX: Probability
#
#                                               summary  \
# 29  Discover concepts and techniques relating to d...
# 23  Understand fundamental concepts relating to st...
# 26  Understand probability and how it manifests in...
#
#                                    course_description
# 29  This course is part three of the MathTrackX XS...
# 23  This course is part six of the MathTrackX XSer...
# 26  This course is part five of the MathTrackX XSe...
#
# Recommendations for course 'Question Everything: Scientific Thinking in Real Life'
#                                 title  \
# 7             Pre-University Calculus
# 19      MathTrackX: Integral Calculus
# 29  MathTrackX: Differential Calculus
#
#                                               summary  \
# 7          Prepare for Introductory Calculus courses.
# 19  Discover concepts and techniques relating to i...
# 29  Discover concepts and techniques relating to d...
#
#                                    course_description
# 7   Mathematics is the language of Science, Engine...
# 19  This course is part four of the MathTrackX XSe...
# 29  This course is part three of the MathTrackX XS...
#
# Recommendations for course 'Introducción a las ecuaciones diferenciales'
#                                         title  \
# 9                  Bases Matemáticas: Álgebra
# 14  Bases Matemáticas: Números y terminología
# 18               Bases Matemáticas: Derivadas
#
#                                               summary  \
# 9   En este curso se tratan los sistemas de ecuaci...
# 14  Se repasan los conceptos básicos de conjuntos,...
# 18  Curso básico sobre funciones y sus derivadas, ...
#
#                                    course_description
# 9   En este curso se recordará lo que es una ecuac...
# 14  Este curso está concebido como una preparación...
# 18  Este curso se concibe como una revisión de los...
#
# Recommendations for course 'Data for Effective Policy Making'
#                                                title  \
# 1   Introduction to Linear Models and Matrix Algebra
# 11          The Math of Data Science: Linear Algebra
# 4                                  Calculus Applied!
#
#                                               summary  \
# 1   Learn to use R programming to apply linear mod...
# 11  This course is an introduction to linear algeb...
# 4   Apply tools of single-variable calculus to cre...
#
#                                    course_description
# 1   Matrix Algebra underlies many of the current t...
# 11  Linear algebra is at the core of all of modern...
# 4   In this course, we go beyond the calculus text...
#
# Recommendations for course 'MathTrackX: Statistics'
#                                 title  \
# 26            MathTrackX: Probability
# 19      MathTrackX: Integral Calculus
# 29  MathTrackX: Differential Calculus
#
#                                               summary  \
# 26  Understand probability and how it manifests in...
# 19  Discover concepts and techniques relating to i...
# 29  Discover concepts and techniques relating to d...
#
#                                    course_description
# 26  This course is part five of the MathTrackX XSe...
# 19  This course is part four of the MathTrackX XSe...
# 29  This course is part three of the MathTrackX XS...
#
# Recommendations for course 'A-level Mathematics for Year 12 - Course 2: Calculus, Newton’s Laws and Hypothesis Testing'
#                                                 title  \
# 6   A-level Mathematics for Year 12 - Course 1: Al...
# 16  A-level Mathematics for Year 13 - Course 1: Fu...
# 7                             Pre-University Calculus
#
#                                        summary  \
# 6                                not available
# 16                               not available
# 7   Prepare for Introductory Calculus courses.
#
#                                    course_description
# 6                                       not available
# 16                                      not available
# 7   Mathematics is the language of Science, Engine...
#
# Recommendations for course 'A-level Mathematics for Year 13 - Course 2: General Motion, Moments and Equilibrium, The Normal Distribution, Vectors, Differentiation Methods, Integration Methods and Differential Equations'
#                                                 title  \
# 16  A-level Mathematics for Year 13 - Course 1: Fu...
# 6   A-level Mathematics for Year 12 - Course 1: Al...
# 29                  MathTrackX: Differential Calculus
#
#                                               summary  \
# 16                                      not available
# 6                                       not available
# 29  Discover concepts and techniques relating to d...
#
#                                    course_description
# 16                                      not available
# 6                                       not available
# 29  This course is part three of the MathTrackX XS...
#
# Recommendations for course 'MathTrackX: Probability'
#                                 title  \
# 23             MathTrackX: Statistics
# 19      MathTrackX: Integral Calculus
# 29  MathTrackX: Differential Calculus
#
#                                               summary  \
# 23  Understand fundamental concepts relating to st...
# 19  Discover concepts and techniques relating to i...
# 29  Discover concepts and techniques relating to d...
#
#                                    course_description
# 23  This course is part six of the MathTrackX XSer...
# 19  This course is part four of the MathTrackX XSe...
# 29  This course is part three of the MathTrackX XS...
#
# Recommendations for course 'AP® Calculus BC'
#                        title  \
# 13  Calculus 1B: Integration
# 7    Pre-University Calculus
# 4          Calculus Applied!
#
#                                               summary  \
# 13  Discover the integral—what it is and how to co...
# 7          Prepare for Introductory Calculus courses.
# 4   Apply tools of single-variable calculus to cre...
#
#                                    course_description
# 13  How long should the handle of your spoon be so...
# 7   Mathematics is the language of Science, Engine...
# 4   In this course, we go beyond the calculus text...
#
# Recommendations for course 'Linear Algebra I: Linear Equations'
#                                                title  \
# 11          The Math of Data Science: Linear Algebra
# 8                College Algebra and Problem Solving
# 1   Introduction to Linear Models and Matrix Algebra
#
#                                               summary  \
# 11  This course is an introduction to linear algeb...
# 8   Learn the basics of Algebra while preparing fo...
# 1   Learn to use R programming to apply linear mod...
#
#                                    course_description
# 11  Linear algebra is at the core of all of modern...
# 8   This course is part of Global Freshman Academy...
# 1   Matrix Algebra underlies many of the current t...
#
# Recommendations for course 'MathTrackX: Differential Calculus'
#                                             title  \
# 19                  MathTrackX: Integral Calculus
# 23                         MathTrackX: Statistics
# 10  MathTrackX: Polynomials, Functions and Graphs
#
#                                               summary  \
# 19  Discover concepts and techniques relating to i...
# 23  Understand fundamental concepts relating to st...
# 10  Develop an understanding of polynomials, funct...
#
#                                    course_description
# 19  This course is part four of the MathTrackX XSe...
# 23  This course is part six of the MathTrackX XSer...
# 10  This course is part one of the MathTrackX XSer...
#
# Recommendations for course 'MathTrackX: Special Functions'
#                                             title  \
# 10  MathTrackX: Polynomials, Functions and Graphs
# 19                  MathTrackX: Integral Calculus
# 29              MathTrackX: Differential Calculus
#
#                                               summary  \
# 10  Develop an understanding of polynomials, funct...
# 19  Discover concepts and techniques relating to i...
# 29  Discover concepts and techniques relating to d...
#
#                                    course_description
# 10  This course is part one of the MathTrackX XSer...
# 19  This course is part four of the MathTrackX XSe...
# 29  This course is part three of the MathTrackX XS...
