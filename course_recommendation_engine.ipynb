# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

df = pd.read_csv("dataset/edx_courses.csv")
df.head()
df.info()
df.drop_duplicates()
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               975 non-null    object
#  1   summary             922 non-null    object
#  2   n_enrolled          855 non-null    object
#  3   course_type         975 non-null    object
#  4   institution         975 non-null    object
#  5   instructors         972 non-null    object
#  6   Level               975 non-null    object
#  7   subject             975 non-null    object
#  8   language            975 non-null    object
#  9   subtitles           972 non-null    object
#  10  course_effort       975 non-null    object
#  11  course_length       975 non-null    object
#  12  price               975 non-null    object
#  13  course_description  935 non-null    object
#  14  course_syllabus     414 non-null    object
#  15  course_url          975 non-null    object
# dtypes: object(16)
# memory usage: 122.0+ KB
# title                   0
# summary                53
# n_enrolled            120
# course_type             0
# institution             0
# instructors             3
# Level                   0
# subject                 0
# language                0
# subtitles               3
# course_effort           0
# course_length           0
# price                   0
# course_description     40
# course_syllabus       561
# course_url              0
# dtype: int64

# %%
text_columns = ['summary', 'instructors', 'subtitles', 'course_description', 'course_syllabus']
df[text_columns] = df[text_columns].fillna('not available')

df.isnull().sum()
df.head()
df.isnull().sum()
# Out:
# title                   0
# summary                 0
# n_enrolled            120
# course_type             0
# institution             0
# instructors             0
# Level                   0
# subject                 0
# language                0
# subtitles               0
# course_effort           0
# course_length           0
# price                   0
# course_description      0
# course_syllabus         0
# course_url              0
# dtype: int64

# %%
df['text'] = df['title'] + ' ' + df['summary'] + ' ' + df['course_description'] + ' ' + df['course_url']
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['text'])

## compute cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# save cosine similarity matrix
np.save('cosine_sim.npy', cosine_sim)

# save dataframe as csv
df.to_csv('edx_courses_processed.csv', index=False)

# %%
def get_recommenations_by_title(title, cosine_sim=cosine_sim):
  if title not in df['title'].values:
    return f"Course titled '{title}' not found"
  idx = df[df['title'] == title].index[0]
  sim_scores = list(enumerate(cosine_sim[idx]))
  sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
  sim_scores = sim_scores[1:4]
  course_indices = [i[0] for i in sim_scores]
  return df[['title', 'summary', 'course_description', 'course_url']].iloc[course_indices]

# %%
recommended_courses = get_recommenations_by_title('Programming for Everybody (Getting Started with Python)')
print(recommended_courses)
# Out:
#                               title  \
# 17   Python Basics for Data Science
# 212          Python Data Structures
# 33        Using Python for Research
#
#                                                summary  \
# 17   This Python course provides a beginner-friendl...
# 212  The second course in Python for Everybody expl...
# 33   Take your introductory knowledge of Python pro...
#
#                                     course_description  \
# 17   Kickstart your learning of Python for data sci...
# 212  This course will introduce the core data struc...
# 33   This course bridges the gap between introducto...
#
#                                             course_url
# 17   https://www.edx.org/course/python-basics-for-d...
# 212  https://www.edx.org/course/python-data-structures
# 33   https://www.edx.org/course/using-python-for-re...

# %%
unique_values = df['subject'].unique()
print(unique_values)
# Out:
# ['Education & Teacher Training' 'Computer Science'
#  'Data Analysis & Statistics' 'Business & Management' 'Communication'
#  'Health & Safety' 'Math' 'Humanities' 'Ethics' 'Economics & Finance'
#  'Food & Nutrition' 'Biology & Life Sciences' 'Social Sciences'
#  'Architecture' 'Medicine' 'Environmental Studies' 'Chemistry'
#  'Art & Culture' 'Language' 'Engineering' 'Philosophy & Ethics'
#  'Electronics' 'History' 'Literature' 'Physics' 'Law' 'Design' 'Science'
#  'Music' 'Energy & Earth Sciences' 'Philanthropy']

# %%
def get_recommenations_by_subject(subject, cosine_sim=cosine_sim):
  subject_df = df[df['subject'].str.contains(subject, case=False, na=False)]

  if subject_df.empty:
    return f"No courses found for the subject '{subject}'"
  subject_df = subject_df.reset_index(drop=True)
  tfidf = TfidfVectorizer(stop_words='english')
  tfidf_matrix = tfidf.fit_transform(subject_df['text'])
  cosine_sim_subject = linear_kernel(tfidf_matrix, tfidf_matrix)

  recommendations = {}
  for idx, row in subject_df.iterrows():
      # Get the pairwise similarity scores of all courses with that course
      sim_scores = list(enumerate(cosine_sim_subject[idx]))

      # Sort the courses based on the similarity scores
      sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

      # Get the scores of the 3 most similar courses
      sim_scores = sim_scores[1:4]

      # Get the course indices
      course_indices = [i[0] for i in sim_scores]

      # Store the recommendations
      recommendations[row['title']] = subject_df[['title', 'summary', 'course_description']].iloc[course_indices]

  return recommendations

# %%
subject_recommendations = get_recommenations_by_subject('Computer Science')
for title, recs in subject_recommendations.items():
  print(f"Recommendations for course '{title}' ")
  print(recs)
  print()
# Out:
# Recommendations for course 'Programming for Everybody (Getting Started with Python)'
#                                   title  \
# 36               Python Data Structures
# 7             Using Python for Research
# 12  Basics of Computing and Programming
#
#                                               summary  \
# 36  The second course in Python for Everybody expl...
# 7   Take your introductory knowledge of Python pro...
# 12  This is a self-paced course from NYU that prov...
#
#                                    course_description
# 36  This course will introduce the core data struc...
# 7   This course bridges the gap between introducto...
# 12  This is a self-paced course that provides an I...
#
# Recommendations for course 'CS50's Introduction to Computer Science'
#                                                 title  \
# 27                                 Programming Basics
# 18  Machine Learning with Python: from Linear Mode...
# 99            Algorithms: Design and Analysis, Part 2
#
#                                               summary  \
# 27  Learn basic computer programming skills and ma...
# 18  An in-depth introduction to the field of machi...
# 99  Welcome to the self paced course, Algorithms: ...
#
#                                    course_description
# 27  Basic concepts of computer programming are int...
# 18  If you have specific questions about this cour...
# 99  Welcome to the self paced course, Algorithms: ...
#
# Recommendations for course 'Marketing Analytics: Marketing Measurement Strategy'
#                                                  title  \
# 20   Marketing Analytics: Competitive Analysis and ...
# 110  Marketing Analytics: Price and Promotion Analy...
# 75   Marketing Analytics: Products, Distribution an...
#
#                                             summary  \
# 20   This course is part of a MicroMasters® Program
# 110  This course is part of a MicroMasters® Program
# 75   This course is part of a MicroMasters® Program
#
#                                     course_description
# 20   In this marketing course, you will learn about...
# 110  In this marketing course, you will learn how t...
# 75   In this marketing course, you will learn how t...
#
# Recommendations for course 'Bitcoin and Cryptocurrencies'
#                                                  title  \
# 49                               Blockchain Technology
# 5              CS50's Introduction to Game Development
# 116  Introducción a la programación en C: Tipos de ...
#
#                                                summary course_description
# 49   This course is part of a Professional Certificate      not available
# 5    This course is part of a Professional Certificate      not available
# 116  This course is part of a Professional Certificate      not available
#
# Recommendations for course 'CS50's Introduction to Artificial Intelligence with Python'
#                                                 title  \
# 26                       Artificial Intelligence (AI)
# 15                 AI for Everyone: Master the Basics
# 18  Machine Learning with Python: from Linear Mode...
#
#                                               summary  \
# 26  Learn the fundamentals of Artificial Intellige...
# 15  Learn what Artificial Intelligence (AI) is by ...
# 18  An in-depth introduction to the field of machi...
#
#                                    course_description
# 26  What do self-driving cars, face recognition, w...
# 15  In this course, you will learn what AI is and ...
# 18  If you have specific questions about this cour...
#
# Recommendations for course 'CS50's Introduction to Game Development'
#                                                 title  \
# 31                    CS50's Understanding Technology
# 77  Introduction to video game development with Unity
# 9                                    CS50 for Lawyers
#
#                                               summary  \
# 31           This course is part of a XSeries Program
# 77  Learn to develop multiplatform videogames usin...
# 9                                       not available
#
#                                    course_description
# 31                                      not available
# 77  Never before has the video game market been at...
# 9                                       not available
#
# Recommendations for course 'CS50's Web Programming with Python and JavaScript'
#                                                  title  \
# 24             Programming for the Web with JavaScript
# 21                             JavaScript Introduction
# 142  Introduction to Cloud Development with HTML5, ...
#
#                                                summary  \
# 24   Learn how to develop dynamic, interactive, and...
# 21   Learn JavaScript, a Web development programmin...
# 142  Learn the key tools and programming languages ...
#
#                                     course_description
# 24   JavaScript is the programming language of the ...
# 21   This course is part of W3C's "Front-End Web De...
# 142  Want to take the first steps to become a Cloud...
#
# Recommendations for course 'Using Python for Research'
#                                                  title  \
# 0    Programming for Everybody (Getting Started wit...
# 36                              Python Data Structures
# 105                    Estructuras de Datos con Python
#
#                                                summary  \
# 0    This course is a "no prerequisite" introductio...
# 36   The second course in Python for Everybody expl...
# 105  El segundo curso en Python for Everybody explo...
#
#                                     course_description
# 0    This course aims to teach everyone the basics ...
# 36   This course will introduce the core data struc...
# 105  Este curso presentará las estructuras de datos...
#
# Recommendations for course 'Excel: Fundamentos y herramientas'
#                                                 title  \
# 16                            Excel: gestión de datos
# 94  Análisis de datos: Diseño y Visualización de T...
# 30                         Introducción al Office 365
#
#                                               summary  \
# 16  En este curso profundizarás en las técnicas y ...
# 94  Aprende cómo transformar datos sin procesar, c...
# 30  Aprende el funcionamiento básico de los compon...
#
#                                    course_description
# 16  Este es un curso de Microsoft Excel de nivel i...
# 94  ¿Luchando con los datos en tu trabajo? ¿Gastan...
# 30  Office 365 constituye una suite ofimática de e...
#
# Recommendations for course 'CS50 for Lawyers'
#                                                 title  \
# 31                    CS50's Understanding Technology
# 5             CS50's Introduction to Game Development
# 25  CS50's Computer Science for Business Professio...
#
#                                               summary  \
# 31           This course is part of a XSeries Program
# 5   This course is part of a Professional Certificate
# 25  This is CS50’s introduction to computer scienc...
#
#                                    course_description
# 31                                      not available
# 5                                       not available
# 25  This is CS50’s introduction to computer scienc...
#
# Recommendations for course 'Introduction to Linux'
#                                               title  \
# 47         Fundamentals of Red Hat Enterprise Linux
# 74         Linux Basics: The Command Line Interface
# 135  C Programming: Using Linux Tools and Libraries
#
#                                                summary  \
# 47                                       not available
# 74   Learn the Linux Command Line interface and bec...
# 135  Learn how to use professional tools and librar...
#
#                                     course_description
# 47   This course will provide you with a basic intr...
# 74   This course will introduce you to Linux, a pow...
# 135  This seventh and final course in the C Program...
#
# Recommendations for course 'Computing in Python I: Fundamentals and Procedural Programming'
#                                            title  \
# 50    Computing in Python II: Control Structures
# 63      Computing in Python III: Data Structures
# 68  Computing in Python IV: Objects & Algorithms
#
#                                               summary  \
# 50  Learn about control structures, one of the mos...
# 63  Learn more complex ways of handling data, incl...
# 68  Learn about recursion, search and sort algorit...
#
#                                    course_description
# 50  Building on your prior knowledge of variables ...
# 63  Build on your existing knowledge of conditiona...
# 68  Complete your introductory knowledge of comput...
#
# Recommendations for course 'Basics of Computing and Programming'
#                                                 title  \
# 39                         Introduction to Networking
# 71            Computer Hardware and Operating Systems
# 0   Programming for Everybody (Getting Started wit...
#
#                                               summary  \
# 39  This is a self-paced course from NYU that prov...
# 71  This is a self-paced course from NYU that prov...
# 0   This course is a "no prerequisite" introductio...
#
#                                    course_description
# 39  This is a self-paced course that provides an I...
# 71  This is a self-paced course that provides an I...
# 0   This course aims to teach everyone the basics ...
#
# Recommendations for course 'HTML5 and CSS Fundamentals'
#                                          title  \
# 32                                  CSS Basics
# 28  HTML5 Coding Essentials and Best Practices
# 72                        HTML5 Apps and Games
#
#                                               summary  \
# 32  Learn how to take your Web pages from bland to...
# 28  Learn how to write Web pages and Web sites by ...
# 72  Today, developers are increasingly moving from...
#
#                                    course_description
# 32  This course is part of W3C's "Front-End Web De...
# 28  HTML5 is the standard language of the Web, dev...
# 72  Want to learn advanced HTML5 tips and techniqu...
#
# Recommendations for course 'Computer Science 101'
#                                                 title  \
# 71            Computer Hardware and Operating Systems
# 87  Computer Vision Fundamentals with Watson and O...
# 25  CS50's Computer Science for Business Professio...
#
#                                               summary  \
# 71  This is a self-paced course from NYU that prov...
# 87  Learn about computer vision, one of the most e...
# 25  This is CS50’s introduction to computer scienc...
#
#                                    course_description
# 71  This is a self-paced course that provides an I...
# 87  Computer Vision is one of the most exciting fi...
# 25  This is CS50’s introduction to computer scienc...
#
# Recommendations for course 'AI for Everyone: Master the Basics'
#                                                  title  \
# 26                        Artificial Intelligence (AI)
# 4    CS50's Introduction to Artificial Intelligence...
# 127                           Deep Learning Essentials
#
#                                                summary  \
# 26   Learn the fundamentals of Artificial Intellige...
# 4    Learn to use machine learning in Python in thi...
# 127  Do you want to learn how machines can learn ta...
#
#                                     course_description
# 26   What do self-driving cars, face recognition, w...
# 4    AI is transforming how we live, work, and play...
# 127  Gain a good understanding of what Deep Learnin...
#
# Recommendations for course 'Excel: gestión de datos'
#                                                  title  \
# 94   Análisis de datos: Diseño y Visualización de T...
# 8                    Excel: Fundamentos y herramientas
# 118  Diseño de sistemas de información gerencial pa...
#
#                                                summary  \
# 94   Aprende cómo transformar datos sin procesar, c...
# 8    En este curso aprenderás las herramientas más ...
# 118  Aprende a crear bases de datos profesionales y...
#
#                                     course_description
# 94   ¿Luchando con los datos en tu trabajo? ¿Gastan...
# 8     Este es un curso introductorio en el que apre...
# 118  En el mundo moderno cualquier empresa u organi...
#
# Recommendations for course 'Programación para todos (empezando con Python)'
#                                                  title  \
# 89   Introducción a la programación en Java: empeza...
# 105                    Estructuras de Datos con Python
# 19                        Python: aprender a programar
#
#                                                summary  \
# 89   ¡Aprende a programar en Java de forma fácil e ...
# 105  El segundo curso en Python for Everybody explo...
# 19   Aprende a programar con Python desde cero. Com...
#
#                                     course_description
# 89   Este es un curso introductorio para aprender p...
# 105  Este curso presentará las estructuras de datos...
# 19   Este curso empieza desde 0 para aprender a pro...
#
# Recommendations for course 'Machine Learning with Python: from Linear Models to Deep Learning'
#                                                 title  \
# 42    Machine Learning for Data Science and Analytics
# 44                                   Machine Learning
# 4   CS50's Introduction to Artificial Intelligence...
#
#                                               summary  \
# 42  Learn the principles of machine learning and t...
# 44  Master the essentials of machine learning and ...
# 4   Learn to use machine learning in Python in thi...
#
#                                    course_description
# 42  Machine Learning is a growing field that is us...
# 44  Machine Learning is the basis for the most exc...
# 4   AI is transforming how we live, work, and play...
#
# Recommendations for course 'Python: aprender a programar'
#                                                  title  \
# 17      Programación para todos (empezando con Python)
# 105                    Estructuras de Datos con Python
# 89   Introducción a la programación en Java: empeza...
#
#                                                summary  \
# 17   Este curso en línea es una introducción "sin p...
# 105  El segundo curso en Python for Everybody explo...
# 89   ¡Aprende a programar en Java de forma fácil e ...
#
#                                     course_description
# 17   Este curso de Python tiene el objetivo de ense...
# 105  Este curso presentará las estructuras de datos...
# 89   Este es un curso introductorio para aprender p...
#
# Recommendations for course 'Marketing Analytics: Competitive Analysis and Market Segmentation'
#                                                  title  \
# 2    Marketing Analytics: Marketing Measurement Str...
# 75   Marketing Analytics: Products, Distribution an...
# 110  Marketing Analytics: Price and Promotion Analy...
#
#                                             summary  \
# 2    This course is part of a MicroMasters® Program
# 75   This course is part of a MicroMasters® Program
# 110  This course is part of a MicroMasters® Program
#
#                                     course_description
# 2    Begin your journey in a new career in marketin...
# 75   In this marketing course, you will learn how t...
# 110  In this marketing course, you will learn how t...
#
# Recommendations for course 'JavaScript Introduction'
#                                                  title  \
# 24             Programming for the Web with JavaScript
# 6    CS50's Web Programming with Python and JavaScript
# 142  Introduction to Cloud Development with HTML5, ...
#
#                                                summary  \
# 24   Learn how to develop dynamic, interactive, and...
# 6    This course picks up where CS50 leaves off, di...
# 142  Learn the key tools and programming languages ...
#
#                                     course_description
# 24   JavaScript is the programming language of the ...
# 6    Topics include database design, scalability, s...
# 142  Want to take the first steps to become a Cloud...
#
# Recommendations for course 'Databases: Relational Databases and SQL'
#                                  title  \
# 134  Databases: Advanced Topics in SQL
# 161     Databases: Modeling and Theory
# 119   Introduction to Database Queries
#
#                                                summary  \
# 134  This course is one of five self-paced courses ...
# 161  This course is one of five self-paced courses ...
# 119  Learn the fundamentals of interacting with rel...
#
#                                     course_description
# 134  About the Database Series of Courses"Databases...
# 161  About the Database Series of Courses"Databases...
# 119  This course is an introduction to the basic co...
#
# Recommendations for course 'C Programming: Getting Started'
#                                                  title  \
# 38                 C Programming: Language Foundations
# 135     C Programming: Using Linux Tools and Libraries
# 101  C Programming: Modular Programming and Memory ...
#
#                                                summary  \
# 38   Master foundational concepts in the C programm...
# 135  Learn how to use professional tools and librar...
# 101  Enhance your coding skills along your path to ...
#
#                                     course_description
# 38   Inthis course, part of the C Programming with ...
# 135  This seventh and final course in the C Program...
# 101  In this course, part of the C Programming with...
#
# Recommendations for course 'Programming for the Web with JavaScript'
#                                                 title  \
# 21                            JavaScript Introduction
# 6   CS50's Web Programming with Python and JavaScript
# 32                                         CSS Basics
#
#                                               summary  \
# 21  Learn JavaScript, a Web development programmin...
# 6   This course picks up where CS50 leaves off, di...
# 32  Learn how to take your Web pages from bland to...
#
#                                    course_description
# 21  This course is part of W3C's "Front-End Web De...
# 6   Topics include database design, scalability, s...
# 32  This course is part of W3C's "Front-End Web De...
#
# Recommendations for course 'CS50's Computer Science for Business Professionals'
#                                       title  \
# 5   CS50's Introduction to Game Development
# 31          CS50's Understanding Technology
# 9                          CS50 for Lawyers
#
#                                               summary course_description
# 5   This course is part of a Professional Certificate      not available
# 31           This course is part of a XSeries Program      not available
# 9                                       not available      not available
#
# Recommendations for course 'Artificial Intelligence (AI)'
#                                                 title  \
# 15                 AI for Everyone: Master the Basics
# 4   CS50's Introduction to Artificial Intelligence...
# 87  Computer Vision Fundamentals with Watson and O...
#
#                                               summary  \
# 15  Learn what Artificial Intelligence (AI) is by ...
# 4   Learn to use machine learning in Python in thi...
# 87  Learn about computer vision, one of the most e...
#
#                                    course_description
# 15  In this course, you will learn what AI is and ...
# 4   AI is transforming how we live, work, and play...
# 87  Computer Vision is one of the most exciting fi...
#
# Recommendations for course 'Programming Basics'
#                                   title  \
# 57          Object-Oriented Programming
# 12  Basics of Computing and Programming
# 23       C Programming: Getting Started
#
#                                               summary  \
# 57  Learn the principles of programming for buildi...
# 12  This is a self-paced course from NYU that prov...
# 23  Start learning one of the most powerful and wi...
#
#                                    course_description
# 57  Go beyond the basics of programming to underst...
# 12  This is a self-paced course that provides an I...
# 23  In this course, you will learn the principles ...
#
# Recommendations for course 'HTML5 Coding Essentials and Best Practices'
#                                                  title  \
# 72                                HTML5 Apps and Games
# 13                          HTML5 and CSS Fundamentals
# 142  Introduction to Cloud Development with HTML5, ...
#
#                                                summary  \
# 72   Today, developers are increasingly moving from...
# 13   Learn how to build Web sites using HTML5 and b...
# 142  Learn the key tools and programming languages ...
#
#                                     course_description
# 72   Want to learn advanced HTML5 tips and techniqu...
# 13   This course is part of W3C's "Front-End Web De...
# 142  Want to take the first steps to become a Cloud...
#
# Recommendations for course 'Algorithms: Design and Analysis, Part 1'
#                                        title  \
# 99   Algorithms: Design and Analysis, Part 2
# 104            Algorithm Design and Analysis
# 48                                Algorithms
#
#                                                summary  \
# 99   Welcome to the self paced course, Algorithms: ...
# 104  Learn about the core principles of computer sc...
# 48   Learn how to structure and use algorithms to s...
#
#                                     course_description
# 99   Welcome to the self paced course, Algorithms: ...
# 104  How do you optimally encode a text file? How d...
# 48   Algorithms power the biggest web companies and...
#
# Recommendations for course 'Introducción al Office 365'
#                                                  title  \
# 8                    Excel: Fundamentos y herramientas
# 123  Introducción al desarrollo de videojuegos con ...
# 108          Introducción a la Inteligencia Artificial
#
#                                                summary  \
# 8    En este curso aprenderás las herramientas más ...
# 123  Aprende a desarrollar videojuegos multiplatafo...
# 108  ¿Es posible construir una máquina o robot inte...
#
#                                     course_description
# 8     Este es un curso introductorio en el que apre...
# 123  Nunca antes el mercado de los videojuegos se h...
# 108  La Inteligencia Artificial (IA) está tomando m...
#
# Recommendations for course 'CS50's Understanding Technology'
#                                       title  \
# 49                    Blockchain Technology
# 5   CS50's Introduction to Game Development
# 9                          CS50 for Lawyers
#
#                                               summary course_description
# 49  This course is part of a Professional Certificate      not available
# 5   This course is part of a Professional Certificate      not available
# 9                                       not available      not available
#
# Recommendations for course 'CSS Basics'
#                                       title  \
# 13               HTML5 and CSS Fundamentals
# 24  Programming for the Web with JavaScript
# 21                  JavaScript Introduction
#
#                                               summary  \
# 13  Learn how to build Web sites using HTML5 and b...
# 24  Learn how to develop dynamic, interactive, and...
# 21  Learn JavaScript, a Web development programmin...
#
#                                    course_description
# 13  This course is part of W3C's "Front-End Web De...
# 24  JavaScript is the programming language of the ...
# 21  This course is part of W3C's "Front-End Web De...
#
# Recommendations for course 'Unlocking Information Security: Part I'
#                                               title  \
# 95          Unlocking Information Security: Part II
# 97               Information Technology Foundations
# 80  Cybersecurity for Critical Urban Infrastructure
#
#                                               summary  \
# 95  Continue learning how systems are hacked and d...
# 97  Information Technology Foundations examines IT...
# 80  Preparing city officials, agency staff and a n...
#
#                                    course_description
# 95  Information Security is everywhere: as the wor...
# 97  Information technology (IT) can be viewed as a...
# 80  Critical urban infrastructure including energy...
#
# Recommendations for course 'Introduction to Cybersecurity'
#                                       title  \
# 160  Finding Your Cybersecurity Career Path
# 151        Building a Cybersecurity Toolkit
# 137          Cybersecurity: The CISO's View
#
#                                                summary  \
# 160  Learn about different career pathways in cyber...
# 151  Develop a set of skills and characteristics th...
# 137  Learn about cybersecurity operations and the r...
#
#                                     course_description
# 160  In this course, you will focus on the pathways...
# 151  Technologies are always being defeated.If you ...
# 137  The Chief Information Security Officer (CISO) ...
#
# Recommendations for course 'Inteligencia Artificial para todos: Domina los fundamentos'
#                                                  title  \
# 108          Introducción a la Inteligencia Artificial
# 98   Introducción a la Inteligencia Artificial de W...
# 109  Introducción a la Inteligencia Artificial: Pri...
#
#                                                summary  \
# 108  ¿Es posible construir una máquina o robot inte...
# 98   Aprende cómo comenzar rápida y fácilmente con ...
# 109  Aprende cómo funcionan los algoritmos de intel...
#
#                                     course_description
# 108  La Inteligencia Artificial (IA) está tomando m...
# 98   En este curso, aprenderás cómo comenzar rápida...
# 109  En este curso lograrás familiarizarte con los ...
#
# Recommendations for course 'Python Data Structures'
#                                                 title  \
# 63           Computing in Python III: Data Structures
# 0   Programming for Everybody (Getting Started wit...
# 92                       Data Structures Fundamentals
#
#                                               summary  \
# 63  Learn more complex ways of handling data, incl...
# 0   This course is a "no prerequisite" introductio...
# 92     This course is part of a MicroMasters® Program
#
#                                    course_description
# 63  Build on your existing knowledge of conditiona...
# 0   This course aims to teach everyone the basics ...
# 92  A good algorithm usually comes together with a...
#
# Recommendations for course 'Introduction to the Internet of Things (IoT)'
#                                     title  \
# 83                IoT Sensors and Devices
# 129            IoT Networks and Protocols
# 55   Cybersecurity and Privacy in the IoT
#
#                                                summary  \
# 83   Explore various IoT devices and sensor types, ...
# 129  Learn about IoT networks and the protocols and...
# 55   Learn about the security and privacy implicati...
#
#                                     course_description
# 83   The Internet of Things (IoT) is expanding at a...
# 129  The Internet of Things (IoT) is expanding at a...
# 55   As the Internet of Things (IoT) continues to g...
#
# Recommendations for course 'C Programming: Language Foundations'
#                                                  title  \
# 23                      C Programming: Getting Started
# 113      C Programming: Pointers and Memory Management
# 101  C Programming: Modular Programming and Memory ...
#
#                                                summary  \
# 23   Start learning one of the most powerful and wi...
# 113  Continue building your coding skills along you...
# 101  Enhance your coding skills along your path to ...
#
#                                     course_description
# 23   In this course, you will learn the principles ...
# 113  In this course, we will examine a key concept,...
# 101  In this course, part of the C Programming with...
#
# Recommendations for course 'Introduction to Networking'
#                                                  title  \
# 12                 Basics of Computing and Programming
# 126  Introduction to Open Source Networking Technol...
# 71             Computer Hardware and Operating Systems
#
#                                                summary  \
# 12   This is a self-paced course from NYU that prov...
# 126  Learn technical fundamentals needed to adopt S...
# 71   This is a self-paced course from NYU that prov...
#
#                                     course_description
# 12   This is a self-paced course that provides an I...
# 126  Explore open source networking projects, from ...
# 71   This is a self-paced course that provides an I...
#
# Recommendations for course 'Introduction to Java Programming: Starting to code in Java'
#                                          title  \
# 76   Introduction to Java Programming – Part 1
# 146  Introduction to Java Programming – Part 2
# 138        Fundamentals of Java EE Development
#
#                                                summary  \
# 76   Learn the fundamental elements of Java program...
# 146  The first MOOC to teach the fundamental elemen...
# 138                                      not available
#
#                                     course_description
# 76   Do you want to become a better problem solver?...
# 146  Do you want to become a better problem solver?...
# 138  This course will provide you with an introduct...
#
# Recommendations for course 'Statistical Thinking for Data Science and Analytics'
#                                                  title  \
# 61    Data Science: Computational Thinking with Python
# 150                       Programming for Data Science
# 153  Enabling Technologies for Data Science and Ana...
#
#                                                summary  \
# 61   Learn the basics of computational thinking, an...
# 150  Learn how to apply fundamental programming con...
# 153  Discover the relationship between Big Data and...
#
#                                     course_description
# 61   We live in an era of unprecedented access to d...
# 150  There is a rising demand for people with the s...
# 153  The Internet of Things is rapidly growing. It ...
#
# Recommendations for course 'Machine Learning for Data Science and Analytics'
#                                                  title  \
# 18   Machine Learning with Python: from Linear Mode...
# 143  Amazon SageMaker: Simplifying Machine Learning...
# 44                                    Machine Learning
#
#                                                summary  \
# 18   An in-depth introduction to the field of machi...
# 143  Learn to integrate Machine Learning into your ...
# 44   Master the essentials of machine learning and ...
#
#                                     course_description
# 18   If you have specific questions about this cour...
# 143  Machine learning is one of the fastest growing...
# 44   Machine Learning is the basis for the most exc...
#
# Recommendations for course 'Introduction to Cloud Infrastructure Technologies'
#                                                  title  \
# 88                     Introduction to Cloud Computing
# 155                    Cloud Computing for Enterprises
# 154  Introduction to Cloud Foundry and Cloud Native...
#
#                                                summary  \
# 88   Master the core concepts in Cloud Computing, f...
# 155  Understand cloud computing technologies and ho...
# 154  A hands-on workshop to learn how to deploy and...
#
#                                     course_description
# 88   This course introduces you to the core concept...
# 155  Organizations are increasingly moving their cr...
# 154  Does your team use Cloud Foundry to deploy app...
#
# Recommendations for course 'Machine Learning'
#                                                  title  \
# 18   Machine Learning with Python: from Linear Mode...
# 42     Machine Learning for Data Science and Analytics
# 127                           Deep Learning Essentials
#
#                                                summary  \
# 18   An in-depth introduction to the field of machi...
# 42   Learn the principles of machine learning and t...
# 127  Do you want to learn how machines can learn ta...
#
#                                     course_description
# 18   If you have specific questions about this cour...
# 42   Machine Learning is a growing field that is us...
# 127  Gain a good understanding of what Deep Learnin...
#
# Recommendations for course 'Introducción al desarrollo de aplicaciones web'
#                                                  title  \
# 59           Introducción a la Ingeniería del Software
# 24             Programming for the Web with JavaScript
# 123  Introducción al desarrollo de videojuegos con ...
#
#                                                summary  \
# 59                                       not available
# 24   Learn how to develop dynamic, interactive, and...
# 123  Aprende a desarrollar videojuegos multiplatafo...
#
#                                     course_description
# 59                                       not available
# 24   JavaScript is the programming language of the ...
# 123  Nunca antes el mercado de los videojuegos se h...
#
# Recommendations for course 'Linear Algebra - Foundations to Frontiers'
#                                                  title  \
# 156  Advanced Linear Algebra: Foundations to Frontiers
# 18   Machine Learning with Python: from Linear Mode...
# 73                     MATLAB and Octave for Beginners
#
#                                                summary  \
# 156       Learn advanced linear algebra for computing.
# 18   An in-depth introduction to the field of machi...
# 73   Learn MATLAB and Octave and start experimentin...
#
#                                     course_description
# 156  Linear algebra is one of the fundamental tools...
# 18   If you have specific questions about this cour...
# 73   Take an exciting crash course in MATLAB and Oc...
#
# Recommendations for course 'Fundamentals of Red Hat Enterprise Linux'
#                                               title  \
# 10                            Introduction to Linux
# 74         Linux Basics: The Command Line Interface
# 135  C Programming: Using Linux Tools and Libraries
#
#                                                summary  \
# 10   Never learned Linux? Want a refresh? Develop a...
# 74   Learn the Linux Command Line interface and bec...
# 135  Learn how to use professional tools and librar...
#
#                                     course_description
# 10   Develop a good working knowledge of Linux usin...
# 74   This course will introduce you to Linux, a pow...
# 135  This seventh and final course in the C Program...
#
# Recommendations for course 'Algorithms'
#                                        title  \
# 29   Algorithms: Design and Analysis, Part 1
# 99   Algorithms: Design and Analysis, Part 2
# 104            Algorithm Design and Analysis
#
#                                                summary  \
# 29   Welcome to the self paced course, Algorithms: ...
# 99   Welcome to the self paced course, Algorithms: ...
# 104  Learn about the core principles of computer sc...
#
#                                     course_description
# 29   Welcome to the self paced course, Algorithms: ...
# 99   Welcome to the self paced course, Algorithms: ...
# 104  How do you optimally encode a text file? How d...
#
# Recommendations for course 'Blockchain Technology'
#                                                 title  \
# 86  Blockchain and FinTech: Basics, Applications, ...
# 31                    CS50's Understanding Technology
# 5             CS50's Introduction to Game Development
#
#                                               summary  \
# 86  Understand the design rationale of blockchain ...
# 31           This course is part of a XSeries Program
# 5   This course is part of a Professional Certificate
#
#                                    course_description
# 86  Blockchain is a core technology in FinTech. Th...
# 31                                      not available
# 5                                       not available
#
# Recommendations for course 'Computing in Python II: Control Structures'
#                                                 title  \
# 63           Computing in Python III: Data Structures
# 11  Computing in Python I: Fundamentals and Proced...
# 68       Computing in Python IV: Objects & Algorithms
#
#                                               summary  \
# 63  Learn more complex ways of handling data, incl...
# 11  Learn the fundamentals of computing in Python,...
# 68  Learn about recursion, search and sort algorit...
#
#                                    course_description
# 63  Build on your existing knowledge of conditiona...
# 11  This course starts from the beginning, coverin...
# 68  Complete your introductory knowledge of comput...
#
# Recommendations for course 'Diseña presentaciones eficaces con Powerpoint'
#                                                  title  \
# 122                                 Buscar en Internet
# 118  Diseño de sistemas de información gerencial pa...
# 84    Introducción a las tecnologías para la Educación
#
#                                                summary  \
# 122  Aprenderás a planificar una búsqueda desde el ...
# 118  Aprende a crear bases de datos profesionales y...
# 84   Aprenderás a sacar partido de las nuevas tecno...
#
#                                     course_description
# 122  En un mundo virtual en el que hay cientos de m...
# 118  En el mundo moderno cualquier empresa u organi...
# 84   Este es un curso destinado a profesores de tod...
#
# Recommendations for course 'Embedded Systems - Shape The World: Microcontroller Input/Output'
#                                                  title  \
# 141  Embedded Systems - Shape The World: Multi-Thre...
# 152  Embedded Systems Essentials with Arm: Getting ...
# 70                  Software Engineering: Introduction
#
#                                                summary  \
# 141                                      not available
# 152  Get practical without hardware. Quickly protot...
# 70   Learn how to apply engineering principles, suc...
#
#                                     course_description
# 141  Learn how electronic gadgets are designed, dev...
# 152  Embedded systems are everywhere – and Arm-base...
# 70   This course, part of the Software Development ...
#
# Recommendations for course 'Android: Introducción a la Programación'
#                                                  title  \
# 89   Introducción a la programación en Java: empeza...
# 93          Introducción a la robótica e industria 4.0
# 108          Introducción a la Inteligencia Artificial
#
#                                                summary  \
# 89   ¡Aprende a programar en Java de forma fácil e ...
# 93   Aprende sobre el apasionante mundo de la robót...
# 108  ¿Es posible construir una máquina o robot inte...
#
#                                     course_description
# 89   Este es un curso introductorio para aprender p...
# 93   El elemento que ha transformado fuertemente el...
# 108  La Inteligencia Artificial (IA) está tomando m...
#
# Recommendations for course 'How to Code: Simple Data'
#                                              title  \
# 157                      How to Code: Complex Data
# 162  Software Construction: Object-Oriented Design
# 70              Software Engineering: Introduction
#
#                                                summary  \
# 157     This course is part of a MicroMasters® Program
# 162     This course is part of a MicroMasters® Program
# 70   Learn how to apply engineering principles, suc...
#
#                                     course_description
# 157  As your program requirements get more complex,...
# 162  This course, part of the Software Development ...
# 70   This course, part of the Software Development ...
#
# Recommendations for course 'Cybersecurity and Privacy in the IoT'
#                                             title  \
# 37   Introduction to the Internet of Things (IoT)
# 129                    IoT Networks and Protocols
# 83                        IoT Sensors and Devices
#
#                                                summary  \
# 37   Gain an understanding of what the IoT is and t...
# 129  Learn about IoT networks and the protocols and...
# 83   Explore various IoT devices and sensor types, ...
#
#                                     course_description
# 37   The Internet of Things (IoT) is expanding at a...
# 129  The Internet of Things (IoT) is expanding at a...
# 83   The Internet of Things (IoT) is expanding at a...
#
# Recommendations for course 'Build your very first iOS app'
#                                                 title  \
# 87  Computer Vision Fundamentals with Watson and O...
# 64                  Software Development Fundamentals
# 23                     C Programming: Getting Started
#
#                                               summary  \
# 87  Learn about computer vision, one of the most e...
# 64  Learn the fundamentals of object-oriented prog...
# 23  Start learning one of the most powerful and wi...
#
#                                    course_description
# 87  Computer Vision is one of the most exciting fi...
# 64  Software developers are in high demand in the ...
# 23  In this course, you will learn the principles ...
#
# Recommendations for course 'Object-Oriented Programming'
#                                              title  \
# 162  Software Construction: Object-Oriented Design
# 64               Software Development Fundamentals
# 27                              Programming Basics
#
#                                                summary  \
# 162     This course is part of a MicroMasters® Program
# 64   Learn the fundamentals of object-oriented prog...
# 27   Learn basic computer programming skills and ma...
#
#                                     course_description
# 162  This course, part of the Software Development ...
# 64   Software developers are in high demand in the ...
# 27   Basic concepts of computer programming are int...
#
# Recommendations for course 'Introduction to Jenkins'
#                                                 title  \
# 70                 Software Engineering: Introduction
# 90  Introduction to DevOps and Site Reliability En...
# 64                  Software Development Fundamentals
#
#                                               summary  \
# 70  Learn how to apply engineering principles, suc...
# 90  Learn how to start transforming your organizat...
# 64  Learn the fundamentals of object-oriented prog...
#
#                                    course_description
# 70  This course, part of the Software Development ...
# 90  As Agile practices started revolutionizing sof...
# 64  Software developers are in high demand in the ...
#
# Recommendations for course 'Introducción a la Ingeniería del Software'
#                                                  title  \
# 145  Diagramas UML estructurales para la Ingeniería...
# 116  Introducción a la programación en C: Tipos de ...
# 93          Introducción a la robótica e industria 4.0
#
#                                                summary  \
# 145  En la era de la información el desarrollo de s...
# 116  This course is part of a Professional Certificate
# 93   Aprende sobre el apasionante mundo de la robót...
#
#                                     course_description
# 145  En la era de la información en la que estamos ...
# 116                                      not available
# 93   El elemento que ha transformado fuertemente el...
#
# Recommendations for course 'Computer Graphics'
#                                                  title  \
# 27                                  Programming Basics
# 87   Computer Vision Fundamentals with Watson and O...
# 101  C Programming: Modular Programming and Memory ...
#
#                                                summary  \
# 27   Learn basic computer programming skills and ma...
# 87   Learn about computer vision, one of the most e...
# 101  Enhance your coding skills along your path to ...
#
#                                     course_description
# 27   Basic concepts of computer programming are int...
# 87   Computer Vision is one of the most exciting fi...
# 101  In this course, part of the C Programming with...
#
# Recommendations for course 'Data Science: Computational Thinking with Python'
#                                                  title  \
# 150                       Programming for Data Science
# 41   Statistical Thinking for Data Science and Anal...
# 36                              Python Data Structures
#
#                                                summary  \
# 150  Learn how to apply fundamental programming con...
# 41   Learn how statistics plays a central role in t...
# 36   The second course in Python for Everybody expl...
#
#                                     course_description
# 150  There is a rising demand for people with the s...
# 41   This statistics and data analysis course will ...
# 36   This course will introduce the core data struc...
#
# Recommendations for course 'Machine Learning (aprendizaje automático) con Python: una introducción práctica'
#                                          title  \
# 130   Modelos predictivos con Machine Learning
# 139  Aprendizaje automático y ciencia de datos
# 108  Introducción a la Inteligencia Artificial
#
#                                                summary  \
# 130  En este curso conocerás los fundamentos del ap...
# 139  Aprende a valorizar y extraer conocimiento a p...
# 108  ¿Es posible construir una máquina o robot inte...
#
#                                     course_description
# 130  La ciencia de los datos es soportada por diver...
# 139  El aprendizaje automático es una habilidad que...
# 108  La Inteligencia Artificial (IA) está tomando m...
#
# Recommendations for course 'Computing in Python III: Data Structures'
#                                            title  \
# 36                        Python Data Structures
# 50    Computing in Python II: Control Structures
# 68  Computing in Python IV: Objects & Algorithms
#
#                                               summary  \
# 36  The second course in Python for Everybody expl...
# 50  Learn about control structures, one of the mos...
# 68  Learn about recursion, search and sort algorit...
#
#                                    course_description
# 36  This course will introduce the core data struc...
# 50  Building on your prior knowledge of variables ...
# 68  Complete your introductory knowledge of comput...
#
# Recommendations for course 'Software Development Fundamentals'
#                                                  title  \
# 131  Automated Software Testing: Unit Testing, Cove...
# 162      Software Construction: Object-Oriented Design
# 79                 Data Structures and Software Design
#
#                                                summary  \
# 131  Learn the software testing techniques, tools, ...
# 162     This course is part of a MicroMasters® Program
# 79   Learn how to select, apply, and analyze the mo...
#
#                                     course_description
# ...
# 104  How do you optimally encode a text file? How d...
#
# Recommendations for course 'Diagramas UML estructurales para la Ingeniería del Software'
#                                                  title  \
# 108          Introducción a la Inteligencia Artificial
# 118  Diseño de sistemas de información gerencial pa...
# 59           Introducción a la Ingeniería del Software
#
#                                                summary  \
# 108  ¿Es posible construir una máquina o robot inte...
# 118  Aprende a crear bases de datos profesionales y...
# 59                                       not available
#
#                                     course_description
# 108  La Inteligencia Artificial (IA) está tomando m...
# 118  En el mundo moderno cualquier empresa u organi...
# 59                                       not available
#
# Recommendations for course 'Introduction to Java Programming – Part 2'
#                                                  title  \
# 76           Introduction to Java Programming – Part 1
# 40   Introduction to Java Programming: Starting to ...
# 138                Fundamentals of Java EE Development
#
#                                                summary  \
# 76   Learn the fundamental elements of Java program...
# 40   Learn to program with Java in an easy and inte...
# 138                                      not available
#
#                                     course_description
# 76   Do you want to become a better problem solver?...
# 40   In this introductory Java programming course, ...
# 138  This course will provide you with an introduct...
#
# Recommendations for course 'UML Class Diagrams for Software Engineering'
#                                                  title  \
# 145  Diagramas UML estructurales para la Ingeniería...
# 70                  Software Engineering: Introduction
# 64                   Software Development Fundamentals
#
#                                                summary  \
# 145  En la era de la información el desarrollo de s...
# 70   Learn how to apply engineering principles, suc...
# 64   Learn the fundamentals of object-oriented prog...
#
#                                     course_description
# 145  En la era de la información en la que estamos ...
# 70   This course, part of the Software Development ...
# 64   Software developers are in high demand in the ...
#
# Recommendations for course 'Driving Digital Innovation through Experimentation'
#                                                  title  \
# 121                                 Big Data Analytics
# 158  Internationalization: Creating Digital Content...
# 150                       Programming for Data Science
#
#                                                summary  \
# 121  Learn key technologies and techniques, includi...
# 158  Learn how a digital product becomes world-read...
# 150  Learn how to apply fundamental programming con...
#
#                                     course_description
# 121  Gain essential skills in today’s digital age t...
# 158  Want to learn how to create a digital product ...
# 150  There is a rising demand for people with the s...
#
# Recommendations for course 'Data Science: Inferential Thinking through Simulations'
#                                                  title  \
# 41   Statistical Thinking for Data Science and Anal...
# 61    Data Science: Computational Thinking with Python
# 150                       Programming for Data Science
#
#                                                summary  \
# 41   Learn how statistics plays a central role in t...
# 61   Learn the basics of computational thinking, an...
# 150  Learn how to apply fundamental programming con...
#
#                                     course_description
# 41   This statistics and data analysis course will ...
# 61   We live in an era of unprecedented access to d...
# 150  There is a rising demand for people with the s...
#
# Recommendations for course 'Programming for Data Science'
#                                                 title  \
# 61   Data Science: Computational Thinking with Python
# 121                                Big Data Analytics
# 112                             Big Data Fundamentals
#
#                                                summary  \
# 61   Learn the basics of computational thinking, an...
# 121  Learn key technologies and techniques, includi...
# 112  Learn how big data is driving organisational c...
#
#                                     course_description
# 61   We live in an era of unprecedented access to d...
# 121  Gain essential skills in today’s digital age t...
# 112  Organizations now have access to massive amoun...
#
# Recommendations for course 'Building a Cybersecurity Toolkit'
#                                       title  \
# 34            Introduction to Cybersecurity
# 160  Finding Your Cybersecurity Career Path
# 137          Cybersecurity: The CISO's View
#
#                                                summary  \
# 34   An introduction to cybersecurity, ideal for le...
# 160  Learn about different career pathways in cyber...
# 137  Learn about cybersecurity operations and the r...
#
#                                     course_description
# 34   This course serves as an introduction to the e...
# 160  In this course, you will focus on the pathways...
# 137  The Chief Information Security Officer (CISO) ...
#
# Recommendations for course 'Embedded Systems Essentials with Arm: Getting Started'
#                                                  title  \
# 141  Embedded Systems - Shape The World: Multi-Thre...
# 66   IoT System Design: Software and Hardware Integ...
# 52   Embedded Systems - Shape The World: Microcontr...
#
#                                                summary  \
# 141                                      not available
# 66   Start developing your own Internet of Things (...
# 52                                       not available
#
#                                     course_description
# 141  Learn how electronic gadgets are designed, dev...
# 66   This course is designed toteach you how system...
# 52   Learn how electronic gadgets are designed, dev...
#
# Recommendations for course 'Enabling Technologies for Data Science and Analytics: The Internet of Things'
#                                             title  \
# 83                        IoT Sensors and Devices
# 37   Introduction to the Internet of Things (IoT)
# 114                  IoT Programming and Big Data
#
#                                                summary  \
# 83   Explore various IoT devices and sensor types, ...
# 37   Gain an understanding of what the IoT is and t...
# 114  Learn how to apply software solutions for diff...
#
#                                     course_description
# 83   The Internet of Things (IoT) is expanding at a...
# 37   The Internet of Things (IoT) is expanding at a...
# 114  The Internet of Things is creating massive qua...
#
# Recommendations for course 'Introduction to Cloud Foundry and Cloud Native Software Architecture'
#                                                  title  \
# 88                     Introduction to Cloud Computing
# 43   Introduction to Cloud Infrastructure Technologies
# 155                    Cloud Computing for Enterprises
#
#                                                summary  \
# 88   Master the core concepts in Cloud Computing, f...
# 43   Learn the fundamentals of building and managin...
# 155  Understand cloud computing technologies and ho...
#
#                                     course_description
# 88   This course introduces you to the core concept...
# 43   New to the cloud and not sure where to begin? ...
# 155  Organizations are increasingly moving their cr...
#
# Recommendations for course 'Cloud Computing for Enterprises'
#                                                  title  \
# 88                     Introduction to Cloud Computing
# 43   Introduction to Cloud Infrastructure Technologies
# 154  Introduction to Cloud Foundry and Cloud Native...
#
#                                                summary  \
# 88   Master the core concepts in Cloud Computing, f...
# 43   Learn the fundamentals of building and managin...
# 154  A hands-on workshop to learn how to deploy and...
#
#                                     course_description
# 88   This course introduces you to the core concept...
# 43   New to the cloud and not sure where to begin? ...
# 154  Does your team use Cloud Foundry to deploy app...
#
# Recommendations for course 'Advanced Linear Algebra: Foundations to Frontiers'
#                                                  title  \
# 46           Linear Algebra - Foundations to Frontiers
# 18   Machine Learning with Python: from Linear Mode...
# 104                      Algorithm Design and Analysis
#
#                                                summary  \
# 46   Learn the mathematics behind linear algebra an...
# 18   An in-depth introduction to the field of machi...
# 104  Learn about the core principles of computer sc...
#
#                                     course_description
# 46   Linear Algebra: Foundations to Frontiers (LAFF...
# 18   If you have specific questions about this cour...
# 104  How do you optimally encode a text file? How d...
#
# Recommendations for course 'How to Code: Complex Data'
#                                              title  \
# 54                        How to Code: Simple Data
# 79             Data Structures and Software Design
# 162  Software Construction: Object-Oriented Design
#
#                                                summary  \
# 54      This course is part of a MicroMasters® Program
# 79   Learn how to select, apply, and analyze the mo...
# 162     This course is part of a MicroMasters® Program
#
#                                     course_description
# 54   This programming course takes a unique approac...
# 79   Knowing how to code is only part of the skills...
# 162  This course, part of the Software Development ...
#
# Recommendations for course 'Internationalization: Creating Digital Content for the World'
#                                                  title  \
# 148  Driving Digital Innovation through Experimenta...
# 141  Embedded Systems - Shape The World: Multi-Thre...
# 79                 Data Structures and Software Design
#
#                                                summary  \
# 148  Learn how to apply principles of experimentati...
# 141                                      not available
# 79   Learn how to select, apply, and analyze the mo...
#
#                                     course_description
# 148  Experimentation is a key capability for any bu...
# 141  Learn how electronic gadgets are designed, dev...
# 79   Knowing how to code is only part of the skills...
#
# Recommendations for course 'Creating Virtual Reality (VR) Apps'
#                                                  title  \
# 77   Introduction to video game development with Unity
# 60                                   Computer Graphics
# 114                       IoT Programming and Big Data
#
#                                                summary  \
# 77   Learn to develop multiplatform videogames usin...
# 60   This course is part of a Professional Certificate
# 114  Learn how to apply software solutions for diff...
#
#                                     course_description
# 77   Never before has the video game market been at...
# 60   Today, computer graphics is a central part of ...
# 114  The Internet of Things is creating massive qua...
#
# Recommendations for course 'Finding Your Cybersecurity Career Path'
#                                 title  \
# 34      Introduction to Cybersecurity
# 151  Building a Cybersecurity Toolkit
# 137    Cybersecurity: The CISO's View
#
#                                                summary  \
# 34   An introduction to cybersecurity, ideal for le...
# 151  Develop a set of skills and characteristics th...
# 137  Learn about cybersecurity operations and the r...
#
#                                     course_description
# 34   This course serves as an introduction to the e...
# 151  Technologies are always being defeated.If you ...
# 137  The Chief Information Security Officer (CISO) ...
#
# Recommendations for course 'Databases: Modeling and Theory'
#                                        title  \
# 22   Databases: Relational Databases and SQL
# 134        Databases: Advanced Topics in SQL
# 119         Introduction to Database Queries
#
#                                                summary  \
# 22   This course is one of five self-paced courses ...
# 134  This course is one of five self-paced courses ...
# 119  Learn the fundamentals of interacting with rel...
#
#                                     course_description
# 22   About the Database Series of Courses"Databases...
# 134  About the Database Series of Courses"Databases...
# 119  This course is an introduction to the basic co...
#
# Recommendations for course 'Software Construction: Object-Oriented Design'
#                                  title  \
# 57         Object-Oriented Programming
# 70  Software Engineering: Introduction
# 64   Software Development Fundamentals
#
#                                               summary  \
# 57  Learn the principles of programming for buildi...
# 70  Learn how to apply engineering principles, suc...
# 64  Learn the fundamentals of object-oriented prog...
#
#                                    course_description
# 57  Go beyond the basics of programming to underst...
# 70  This course, part of the Software Development ...
# 64  Software developers are in high demand in the ...
#
# Recommendations for course 'Introduction to Hyperledger Sovereign Identity Blockchain Solutions: Indy, Aries & Ursa'
#                                                  title  \
# 86   Blockchain and FinTech: Basics, Applications, ...
# 49                               Blockchain Technology
# 148  Driving Digital Innovation through Experimenta...
#
#                                                summary  \
# 86   Understand the design rationale of blockchain ...
# 49   This course is part of a Professional Certificate
# 148  Learn how to apply principles of experimentati...
#
#                                     course_description
# 86   Blockchain is a core technology in FinTech. Th...
# 49                                       not available
# 148  Experimentation is a key capability for any bu...
#
# Recommendations for course 'A System View of Communications: From Signals to Packets (Part 1)'
#                                   title  \
# 97   Information Technology Foundations
# 91     Network and Security Foundations
# 137      Cybersecurity: The CISO's View
#
#                                                summary  \
# 97   Information Technology Foundations examines IT...
# 91   This course introduces the components of a com...
# 137  Learn about cybersecurity operations and the r...
#
#                                     course_description
# 97   Information technology (IT) can be viewed as a...
# 91   As computer systems become smaller, cheaper, a...
# 137  The Chief Information Security Officer (CISO) ...
#
# Recommendations for course 'Scripting and Programming Foundations'
#                                                  title  \
# 61    Data Science: Computational Thinking with Python
# 40   Introduction to Java Programming: Starting to ...
# 104                      Algorithm Design and Analysis
#
#                                                summary  \
# 61   Learn the basics of computational thinking, an...
# 40   Learn to program with Java in an easy and inte...
# 104  Learn about the core principles of computer sc...
#
#                                     course_description
# 61   We live in an era of unprecedented access to d...
# 40   In this introductory Java programming course, ...
# 104  How do you optimally encode a text file? How d...
